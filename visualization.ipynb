# %%
# %load_ext autoreload
# %autoreload 2

from dataset import Dataset
from visualizer import Visualizer, SemanticVisualizer

# Load dataset
ds = Dataset()
ds.load('data/DJI_0012')

# %% [markdown]
# # Pyplot Visualizer

# %%
# Instantiate the visualizer object
vis = Visualizer(ds)

# %% [markdown]
# ## Plot the entire frame

# %%
# Plot frame
scene = ds.get('scene', ds.list_scenes()[0])
vis.plot_frame(scene['first_frame'])

# %% [markdown]
# ## Highlight the specified instance in this frame

# %%
# Plot a certain instance
frame = ds.get('frame', scene['first_frame'])
vis.plot_instance(frame['instances'][0])
# Out:
# The type of this instance is Car

# %%
print(ds.states_from_utm(frame['instances'][0]))
# Out:
# {'coords': array([88.55, 63.48]), 'heading': 1.328607346410207, 'speed': -0.23, 'acceleration': [0.0056, 0.0089], 'mode': 'moving'}

# %% [markdown]
# # Semantic Visualizer

# %%
smt_vis = SemanticVisualizer(ds)

# %% [markdown]
# ## Plot the entire frame

# %%
scene = ds.get('scene', ds.list_scenes()[0])
smt_vis.plot_frame(scene['first_frame'])
# Out:
# <PIL.Image.Image image mode=RGB size=1400x800 at 0x7F21AB17E190>

# %% [markdown]
# ## Plot the instance-centric crop

# %%
frame = ds.get('frame', scene['first_frame'])
smt_vis.plot_instance_local(frame['instances'][0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F21A93C8040>
